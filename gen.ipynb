# %%
def gen_values():
    yield 1
    yield 2
    yield 3
'''
calling a generator simply creates a generator object
'''

gen = gen_values()
print(next(gen))
print(next(gen))
print(next(gen))
# Out:
# 1
# 2
# 3
